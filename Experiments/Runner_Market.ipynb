# %%
# !git clone https://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@github.com/Anunay-Yadav/ARM_MTL.git
# Out:
# Cloning into 'ARM_MTL'...
# remote: Enumerating objects: 607, done.
# remote: Counting objects: 100% (607/607), done.
# remote: Compressing objects: 100% (329/329), done.
# remote: Total 607 (delta 291), reused 587 (delta 274), pack-reused 0
# Receiving objects: 100% (607/607), 28.11 MiB | 10.79 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Checking out files: 100% (536/536), done.

# %%
# %cd ARM_MTL
# Out:
# /content/ARM_MTL

# %%
# !pip3 install higher

# %%
# !python3 algorithm.py
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:338: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
# ---------------EPOCH 0 ----------------------
# MSE LOSS:  255.90463241106383
# MSE LOSS:  370.72417220350695
# MSE LOSS:  393.5640265474053
# MSE LOSS:  417.2090924448115
# MSE LOSS:  422.305885184859
# MSE LOSS:  311.56351137885963
# Accuracy:  0.3157463768115944
# Accuracy:  0.15571014492753624
# Accuracy:  0.21265942028985513
# Accuracy:  0.17118115942028986
# ---------------EPOCH 1 ----------------------
# ---------------EPOCH 2 ----------------------
# ---------------EPOCH 3 ----------------------
# ---------------EPOCH 4 ----------------------
# ---------------EPOCH 5 ----------------------
# ...
