# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Bert_Lime/IMDB/
# Out:
# /content/drive/MyDrive/Bert_Lime/IMDB

# %%
import matplotlib.pyplot as plt
import pickle
# list_of_models = ["Mid_Gaussian.pkl", "Uniform.pkl", "16.pkl", "32.pkl", "64.pkl", "128.pkl", "192.pkl", "256.pkl", "356.pkl"]
list_of_models = ["32.pkl", "64.pkl","256.pkl", "Mid_Gaussian.pkl"]
data_path = "Model_longformer/data_"
for i in list_of_models:
    data_temp = data_path + i
    with open(data_temp, "rb") as f:
      data = pickle.load(f)
      stats_list = data[2]
      train_loss_list = data[0]
      test_loss_list = data[1]
    new_train_loss = []
    for j in range(0, len(train_loss_list), 500):
        new_train_loss.append(sum(train_loss_list[j:j + 500]) / len(train_loss_list[j:j + 500]))
    # print(new_train_loss)
    plt.plot([i for i in range(len(new_train_loss))] ,new_train_loss, label = i)

plt.xlabel("Iteration")
plt.ylabel("loss")
plt.legend()
plt.title("Model performence train")
# Out:
# Text(0.5, 1.0, 'Model performence train')

# %%
import matplotlib.pyplot as plt
import pickle
# list_of_models = ["Mid_Gaussian.pkl", "Uniform.pkl", "16.pkl", "32.pkl", "64.pkl", "128.pkl", "192.pkl", "256.pkl", "356.pkl"]
list_of_models = ["32.pkl", "64.pkl","256.pkl", "Mid_Gaussian.pkl"]

data_path = "Model_longformer/data_"
for i in list_of_models:
    data_temp = data_path + i
    with open(data_temp, "rb") as f:
      data = pickle.load(f)
      stats_list = data[2]
      train_loss_list = data[0]
      test_loss_list = data[1]
    new_test_loss = []
    for j in range(0, len(test_loss_list), 500):
        new_test_loss.append(sum(test_loss_list[j:j + 500]) / len(test_loss_list[j:j + 500]))
    plt.plot([i for i in range(len(new_test_loss))] ,new_test_loss, label = i)

plt.xlabel("Iteration")
plt.ylabel("loss")
plt.legend()
plt.title("Model performence test")
# Out:
# Text(0.5, 1.0, 'Model performence test')

# %%
import matplotlib.pyplot as plt
import pickle
# list_of_models = ["Mid_Gaussian.pkl", "Uniform.pkl", "16.pkl", "32.pkl", "64.pkl", "128.pkl", "192.pkl", "256.pkl", "356.pkl"]
list_of_models = ["32.pkl", "64.pkl","256.pkl", "Mid_Gaussian.pkl"]

data_path = "Model_longformer/data_"
for i in list_of_models:
    data_temp = data_path + i
    with open(data_temp, "rb") as f:
      data = pickle.load(f)
      stats_list = data[2]
      train_loss_list = data[0]
      test_loss_list = data[1]
    # print(stats_list)
    plt.scatter([i for i in range(len(stats_list))] ,[i[0]['accuracy'] for i in stats_list], label = i)

plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Model performence accuracy")
# Out:
# Text(0.5, 1.0, 'Model performence accuracy')

# %%
import matplotlib.pyplot as plt
import pickle
# list_of_models = ["Mid_Gaussian.pkl", "Uniform.pkl", "16.pkl", "32.pkl", "64.pkl", "128.pkl", "192.pkl", "256.pkl", "356.pkl"]
list_of_models = ["32.pkl", "64.pkl","256.pkl", "Mid_Gaussian.pkl"]

data_path = "Model_longformer/data_"
for i in list_of_models:
    data_temp = data_path + i
    with open(data_temp, "rb") as f:
      data = pickle.load(f)
      stats_list = data[2]
      train_loss_list = data[0]
      test_loss_list = data[1]
    plt.scatter([i for i in range(len(stats_list))] ,[i[1]['precision'] for i in stats_list], label = i)

plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Model performence precision")
# Out:
# Text(0.5, 1.0, 'Model performence precision')

# %%
import matplotlib.pyplot as plt
import pickle
# list_of_models = ["Mid_Gaussian.pkl", "Uniform.pkl", "16.pkl", "32.pkl", "64.pkl", "128.pkl", "192.pkl", "256.pkl", "356.pkl"]
list_of_models = ["32.pkl", "64.pkl","256.pkl", "Mid_Gaussian.pkl"]
data_path = "Model_longformer/data_"
for i in list_of_models:
    data_temp = data_path + i
    with open(data_temp, "rb") as f:
      data = pickle.load(f)
      stats_list = data[2]
      train_loss_list = data[0]
      test_loss_list = data[1]
    plt.scatter([i for i in range(len(stats_list))] ,[i[2]['f1'] for i in stats_list], label = i)

plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Model performence f1")
# Out:
# Text(0.5, 1.0, 'Model performence f1')

# %%
import matplotlib.pyplot as plt
import pickle
# list_of_models = ["Mid_Gaussian.pkl", "Uniform.pkl", "16.pkl", "32.pkl", "64.pkl", "128.pkl", "192.pkl", "256.pkl", "356.pkl"]
list_of_models = ["32.pkl", "64.pkl","256.pkl", "Mid_Gaussian.pkl"]
data_path = "Model_longformer/data_"
for i in list_of_models:
    data_temp = data_path + i
    with open(data_temp, "rb") as f:
      data = pickle.load(f)
      stats_list = data[2]
      train_loss_list = data[0]
      test_loss_list = data[1]
    plt.scatter([i for i in range(len(stats_list))] ,[i[3]['recall'] for i in stats_list], label = i)

plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Model performence recall")
# Out:
# Text(0.5, 1.0, 'Model performence recall')
